# %%
import pandas as pd

# %%
data = pd.read_csv("./loan_data.csv")
data.head(3)
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
#
#    delinq.2yrs  pub.rec  not.fully.paid
# 0            0        0               0
# 1            0        0               0
# 2            0        0               0

# %%
variables_of_interest = ["credit.policy", "int.rate", "log.annual.inc", "dti", "fico", "revol.bal"]
data_var_int = data[variables_of_interest]
data_var_int.head(3)
# Out:
#    credit.policy  int.rate  log.annual.inc    dti  fico  revol.bal
# 0              1    0.1189       11.350407  19.48   737      28854
# 1              1    0.1071       11.082143  14.29   707      33623
# 2              1    0.1357       10.373491  11.63   682       3511

# %%
import seaborn as sns

# %%
sns.heatmap(data_var_int.corr(), square= True)
# Out:
# <Axes: >

# %%
sns.heatmap(data.corr(), square= True)
# Out:
# <Axes: >

# %%
round(data_var_int.corr(), 2)
# Out:
#                 credit.policy  int.rate  log.annual.inc   dti  fico  revol.bal
# credit.policy            1.00     -0.29            0.03 -0.09  0.35      -0.19
# int.rate                -0.29      1.00            0.06  0.22 -0.71       0.09
# log.annual.inc           0.03      0.06            1.00 -0.05  0.11       0.37
# dti                     -0.09      0.22           -0.05  1.00 -0.24       0.19
# fico                     0.35     -0.71            0.11 -0.24  1.00      -0.02
# revol.bal               -0.19      0.09            0.37  0.19 -0.02       1.00
